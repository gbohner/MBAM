# %%
using NBInclude
nbinclude("MBAM.ipynb")
nbinclude("Test/MINPACK-2\ Thermistor.ipynb")
# Out:
# reduce (generic function with 1 method)

# %%
phi0=[5.609e-3, 6180.0, 345.0];
T = collect(50:5:125)'
y0 = model(phi0, T);

# %%
phi0_paper=[5.609e-3, exp(11), exp(8)];
outp = MBAM(model, phi0_paper, T, model_iters=[0], move_dir=[1], boundary_time=10000, verbose=1, maxEV=1e-10, maxVnorm=[1e-1, 5e-3]);
# Out:
#   0.000028 seconds (34 allocations: 2.859 KB)
# Model iteration 0, Single g_cost call takes:
#   0.000023 seconds (42 allocations: 3.359 KB)
# Model iteration 0, initial values:
#       D = [  1.04e-01,   6.13e+04,   1.70e+09]
# phi_cur = [     -5.18,      10.00,       7.50]
#       v = [  9.82e-01,  -1.69e-01,  -8.83e-02]
#
#
# Model iteration 0, final values:
#       D = [  1.00e-10,   1.07e+05,   8.00e+06]
# phi_cur = [      5.95,       3.65,     -11.71]
#       v = [  5.17e-08,  -2.23e-07,  -1.00e+00]
#
#
# data_dim = (1,)
# Model_reduce - step 1 - Symbolic expression read
# y_symb = phi1*exp(phi2/(phi3 + x1))
# Model_reduce - step 2/1/1 - Phi combinations inds done
# inds = [3]
# Model_reduce - step 2/1/2 - Phi combinations ext done
# phi_ext = Any[phi1,phi2,phi3,1/phi1,1/phi2,1/phi3]
# Model_reduce - step 2/1 - Phi combinations done
# phi_comb = Any[]
#   0.000865 seconds (79 allocations: 3.688 KB)
# Model_reduce - step 2/2 - Eta vec done
# eta = Any[]
# Model_reduce - step 2/3 - Symbolic substitutions done
#
#
# Model_reduce - step 2 - Parameter combinations substituted
# Model_reduce - step 3 - Limits taken
#   0.001987 seconds (79 allocations: 3.688 KB)
# Model_reduce - step 4 - Reduction done
# Model_reduce - step 5 - Callable function done
# Model_reduce - step 6 - Numeric reduction done
#   0.044271 seconds (5.27 k allocations: 224.673 KB)
# (model_reduced[n1])[2] = phi1*exp(phi2/x1)
# (model_reduced[n1])[3] = Dict{Any,Any}(phi1=>phi1,phi2=>phi2)

# %%
using Plots

# Plotting the geodesic in the phi2 - phi3 plane
Plots.plot(hcat(outp[7]...)[2,:]', hcat(outp[7]...)[3,:]', xlabel = "phi2", ylabel= "phi3", xlims=[1; 10])
# Out:
# <html>
# <head>
#      <script src="/Users/gergobohner/.julia/v0.4/PlotlyJS/deps/plotly-latest.min.js"></script>
# </head>
# <body>
#      <div id="fcbcac71-4072-4617-a19e-92f25daef874" class="plotly-graph-div"></div>
#
# <script>
#     window.PLOTLYENV=window.PLOTLYENV || {};
#     window.PLOTLYENV.BASE_URL="https://plot.ly";
#    Plotly.newPlot('fcbcac71-4072-4617-a19e-92f25daef874', [{"yaxis":"y","y":[7.5,7.49911214125133,7.4779613679114885,7.4554363617100705,7.432865162168522,7.410355261735551,7.387918761430902,7.365559937623077,7.3432832320173596,7.321094288978209,7.298999295115347,7.277006675360903,7.255124802479082,7.233364050315848,7.211736516439357,7.190257440142082,7.168942700395055,7.147812434544745,7.126889457289334,7.106200453495923,7.085776281489549,7.065652999398579,7.045872514006835,7.026482751429925,7.007539588368469,6.989107101294251,6.971258791839574,6.954078922190921,6.937664432573455,6.922127905325043,6.90