# %%
using NBInclude
nbinclude("MBAM.ipynb")
nbinclude("Test/MINPACK-2\ Thermistor.ipynb")
# Out:
# reduce (generic function with 1 method)

# %%
phi0=[5.609e-3, 6180.0, 345.0];
T = collect(50:5:125)'
y0 = model(phi0, T);

# %%
outp = MBAM(model, phi0, T, model_iters=[0], move_dir=[1], boundary_time=100, verbose=1, maxEV=1e-2, maxVnorm=[1e-1, 5e-2]);
# Out:
#   0.011164 seconds (6.30 k allocations: 302.218 KB)
# Model iteration 0, Single g_cost call takes:
#   0.020362 seconds (10.91 k allocations: 525.776 KB)
# Model iteration 0, initial values:
#       D = [  8.53e+03,   3.57e+08,   1.58e+12]
# phi_cur = [     -5.18,       8.73,       5.84]
#       v = [  9.88e-01,  -1.33e-01,  -8.02e-02]
#
#
# Model iteration 0, final values:
#       D = [  1.00e-02,   1.28e+08,   3.68e+10]
# phi_cur = [      7.20,       5.12,      -7.04]
#       v = [  3.26e-05,  -2.69e-05,  -1.00e+00]
#
#
# data_dim = (1,)
# Model_reduce - step 1 - Symbolic expression read
# y_symb = phi1*exp(phi2/(phi3 + x1))
# Model_reduce - step 2/1/1 - Phi combinations inds done
# inds = [3]
# Model_reduce - step 2/1/2 - Phi combinations ext done
# phi_ext = Any[phi1,phi2,phi3,1/phi1,1/phi2,1/phi3]
# Model_reduce - step 2/1 - Phi combinations done
# phi_comb = Any[]
#   0.001180 seconds (79 allocations: 3.688 KB)
# Model_reduce - step 2/2 - Eta vec done
# eta = Any[]
# ...

# %%
using Plots

# Plotting the geodesic in the phi2 - phi3 plane
Plots.plot(hcat(outp[7]...)[2,:]', hcat(outp[7]...)[3,:]', xlabel = "phi2", ylabel= "phi3")
# Out:
# <html>
# <head>
#      <script src="/Users/gergobohner/.julia/v0.4/PlotlyJS/deps/plotly-latest.min.js"></script>
# </head>
# <body>
#      <div id="7a78d5fc-9aac-408e-bd75-4a87e9ae9b14" class="plotly-graph-div"></div>
#
# <script>
#     window.PLOTLYENV=window.PLOTLYENV || {};
#     window.PLOTLYENV.BASE_URL="https://plot.ly";
# ...
